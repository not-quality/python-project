# %%
import requests
import json
import pandas as pd

"""一级数据采集"""
job = []
salary = []
practice_time = []
href1 = []
href2 = []
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36 Edg/138.0.0.0'}
url_js = f'https://www.ciwei.net/api/Shixi_Pc/search?city=0&getCount=1&s_c=1&page=1&source=pc'
web_js = requests.get(url_js, headers=headers)                      # 发送访问请求
json_text = json.loads(web_js.text)
# 将列表转化为数据框架，以便于通过key获取value
data = pd.DataFrame(json_text['data']['lists'])
job.extend(data["title"])                                           # 对网页源码进行解析
salary.extend(data["salary"])                                       # 工作岗位
practice_time.extend(data["work_time_string"])                      # 薪资待遇
href1.extend(data["jobid"])                                         # 岗位详情网址ID
href2.extend(data["company_id"])                                    # 公司详情网址ID

# 数据保存
data_dic_1 = {
'岗位名称': job,
'薪资待遇': salary,
'实习时长': practice_time,
'岗位详情网址ID': href1,
'公司详情网址ID': href2
}

job_1 = pd.DataFrame(data_dic_1)
job_1
# Out:
#                                           岗位名称        薪资待遇 实习时长  岗位详情网址ID  \
# 0                                  线上运营志愿者（长期）          面议  3个月    329797
# 1                                        信审实习生  150-180元/天  6个月    335782
# 2                                        市场实习生  150-200元/天  3个月    218306
# 3  棕榈资本2025实习生转正名额等你锁定！【投资实习生/分析师 - AI方向150/天】  145-150元/天  3个月    335804
# 4                                 人力资源/hrbp实习生   50-100元/天  3个月    331388
# 5           Intern – Recruiting Associate/招聘顾问  140-150元/天  4个月    296311
# 6           Industry Research Assistant Intern  100-150元/天   长期    335765
# 7                                       新媒体实习生  150-200元/天   长期    138858
# 8                                         实习编辑  100-120元/天  3个月    270830
# 9                                      营销编辑实习生  100-120元/天  3个月    324163
#
#    公司详情网址ID
# 0     11727
# 1     45955
# 2     20798
# 3     45887
# 4     23089
# 5     42357
# 6     42357
# 7     20798
# 8     26220
# 9     26220

# %%
import time
import random

describe = []
educational = []
release_time = []
headcount = []
company = []
size = []
address = []
trade = []    
"""二级数据采集"""
for j in href1:
    url_sub1 = 'https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid={}'.format(j)    # 二级页面的网址
    web_sub1 = requests.get(url_sub1, headers=headers)
    json_sub1 = json.loads(web_sub1.text)
    data_sub1 = json_sub1['data']['jobInfo']
    describe.append(data_sub1["fduty"])                         # 获取工作描述
    educational.append(data_sub1["education"])                  # 学历要求
    headcount.append(data_sub1["num"])                          # 招聘人数
    release_time.append(data_sub1["refresh_time"])              # 发布时间
    # 随机时间
    delay = random.uniform(0.5, 1)
    time.sleep(delay)

for k in href2:
    url_sub2 = 'https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id={}'.format(k)    # 二级页面的网址
    web_sub2 = requests.get(url_sub2, headers=headers)
    json_sub1 = json.loads(web_sub2.text)
    data_sub1 = json_sub1['data']['companyInfo']
    company.append(data_sub1["comname"])                        # 公司名称
    size.append(data_sub1["scale"])                             # 公司规模
    address.append(data_sub1["provinces_string"])               # 企业地点
    trade.append(data_sub1["industry_string"])                  # 公司领域
    # 随机时间
    delay = random.uniform(0.5, 1)
    time.sleep(delay)

data_dic_2 = {
    '工作描述': describe,
    '学历要求': educational,
    '招聘人数': headcount,
    '发布时间': release_time,
    '公司名称': company,
    '公司规模': size,
    '工作地点': address,
    '企业领域': trade
}
# 循环采集时不可用的
job_2 = pd.DataFrame(data_dic_2)
job_2
# Out:
#                                                 工作描述 学历要求  招聘人数  \
# 0  1. 后台投稿处理，及文章排版工作（公众号文章排版）\n2. 作者相关工作：文章授权、作者要...   大专     2
# 1  1. 协助信审团队，对融资租赁项目涉及的企业资料进行信息梳理与核对，确保资料完整、数据准确；...   本科     1
# 2  1、根据项目特点撰写宣传文案；\n2、能够进行英文资料翻译和日常的语言沟通；\n3、配合完成...   本科     2
# 3  【工作内容】\n\n1、深度参与并挖掘早期AI创业项目，参与项目筛选或细分赛道的行业mapp...   本科     5
# 4  1. 负责完成公司的招聘目标，快速满足各部门的招聘需求；\n2. 每天开拓和维护各类招聘渠道...   本科     5
# 5  - Collaboration with the Associate team to sup...   本科     1
# 6  Location: Shanghai or Hong Kong\nInternship Ty...   本科     2
# 7  负责微信、微博、抖音、B站等自媒体平台的日常运营及推广工作；\n思维敏捷、活跃，具有敏锐捕捉...   本科     2
# 8  1、负责公众号的内容排版，配图，等一应相关执行类工作；  \n2、负责电商店铺的售前、售后等...   本科     1
# 9  岗位职责：\n1、协助编辑图书在传统媒体及新媒体的宣传推广工作，包括营销文案、书讯、书评等撰...   本科     1
#
#                发布时间      公司名称        公司规模 工作地点         企业领域
# 0  2025-07-03 17:41  人人都是产品经理    101~300人   广东         教育培训
# 1  2025-07-02 12:07       亿多世    101~300人   广东           金融
# 2  2025-07-04 10:09      四海一家      11~50人   北京  广告|传媒|文化|体育
# 3  2025-07-03 13:04      棕榈资本      11~50人   上海           金融
# 4  2025-07-04 11:56        腾讯    3001人及以上   北京    互联网|游戏|软件
# 5  2025-07-01 15:12     Amrop  1001~3000人   上海   咨询/法律/人力资源
# 6  2025-07-01 16:28     Amrop  1001~3000人   上海   咨询/法律/人力资源
# 7  2025-07-04 10:09      四海一家      11~50人   北京  广告|传媒|文化|体育
# 8  2025-07-01 13:28    中南博集天卷    101~300人   北京  广告|传媒|文化|体育
# 9  2025-07-01 13:28    中南博集天卷    101~300人   北京  广告|传媒|文化|体育

# %%
"""数据采集"""
job = []
salary = []
practice_time = []
describe = []
educational = []
release_time = []
headcount = []
company = []
size = []
address = []
trade = []

n = 2
count = 0
for i in range(n):
    count += 1
    print(f'正在第{count}个一级页面')
    """一级数据采集"""
    href1 = []
    href2 = []
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36 Edg/138.0.0.0'}
    url_js = f'https://www.ciwei.net/api/Shixi_Pc/search?city=0&getCount=1&s_c=1&page={count}&source=pc'
    web_js = requests.get(url_js, headers=headers)                  # 发送访问请求
    json_text = json.loads(web_js.text)
    # 将列表转化为数据框架，以便于通过key获取value
    data = pd.DataFrame(json_text['data']['lists'])
    job.extend(data["title"])                                       # 对网页源码进行解析
    salary.extend(data["salary"])                                   # 工作岗位
    practice_time.extend(data["work_time_string"])                  # 薪资待遇
    href1.extend(data["jobid"])                                     #岗位详情网址ID
    href2.extend(data["company_id"])                                #公司详情网址ID


    """二级数据采集"""
    for j in href1:
        url_sub1 = 'https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid={}'.format(j)    # 二级页面的网址
        print('...正在爬取【岗位详情】二级网页：{}'.format(url_sub1))
        web_sub1 = requests.get(url_sub1, headers=headers)
        json_sub1 = json.loads(web_sub1.text)
        data_sub1 = json_sub1['data']['jobInfo']
        describe.append(data_sub1["fduty"])                         # 获取工作描述
        educational.append(data_sub1["education"])                  # 学历要求
        headcount.append(data_sub1["num"])                          # 招聘人数
        release_time.append(data_sub1["refresh_time"])              # 发布时间
        # 随机时间
        delay = random.uniform(0.5, 1)
        time.sleep(delay)

    for k in href2:
        url_sub2 = 'https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id={}'.format(k)    # 二级页面的网址
        print('...正在爬取【公司详情】二级网页：{}'.format(url_sub2))
        web_sub2 = requests.get(url_sub2, headers=headers)
        json_sub1 = json.loads(web_sub2.text)
        data_sub1 = json_sub1['data']['companyInfo']
        company.append(data_sub1["comname"])                        # 公司名称
        size.append(data_sub1["scale"])                             # 公司规模
        address.append(data_sub1["provinces_string"])               # 企业地点
        trade.append(data_sub1["industry_string"])                  # 公司领域
        # 随机时间
        delay = random.uniform(0.5, 1)
        time.sleep(delay)


# 数据保存
data_dic = {
    '岗位名称': job,
    '薪资待遇': salary,
    '实习时长': practice_time,
    '工作描述': describe,
    '学历要求': educational,
    '招聘人数': headcount,
    '发布时间': release_time,
    '公司名称': company,
    '公司规模': size,
    '工作地点': address,
    '企业领域': trade
}

job_information = pd.DataFrame(data_dic)
job_information.to_csv('job_information.csv', encoding='utf-8-sig', index=None,mode='a')
print(job_information.shape)
# Out:
# 正在第1个一级页面
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=329797
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=335782
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=218306
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=335804
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=331388
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=296311
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=335765
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=138858
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=270830
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=324163
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=11727
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=45955
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=20798
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=45887
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=23089
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=42357
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=42357
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=20798
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=26220
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=26220
# 正在第2个一级页面
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=275608
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=335764
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=335724
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=325161
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=307513
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=335766
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=311681
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=335587
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=335682
# ...正在爬取【岗位详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Job/detail?jobid=242674
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=26220
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=39957
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=36293
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=35824
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=35824
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=30277
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=3401
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=3401
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=45870
# ...正在爬取【公司详情】二级网页：https://www.ciwei.net/api/Shixi_V2_Company/detail?company_id=26220
# (20, 11)
